# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv("ecommerce_customer_data_large.csv")

# %%
X = df[["Customer Age","Total Purchase Amount","Quantity"]]

# %%
scaler = StandardScaler()

X_scaled = scaler.fit_transform(X)

# %%
kmeans = KMeans(n_clusters=4,random_state=42)

df["Cluster"] = kmeans.fit_predict(X_scaled)

# %%
plt.figure(figsize=(8,6))

sns.scatterplot(
    data=df,
    x="Customer Age",
    y="Total Purchase Amount",
    hue="Cluster",
    palette="Set2"
)

plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
df.groupby("Cluster")[["Customer Age","Total Purchase Amount","Quantity"]].mean()
# Out:
#          Customer Age  Total Purchase Amount  Quantity
# Cluster
# 0           58.231518            1589.645922  3.218904
# 1           45.054158            3734.118389  1.429312
# 2           29.116908            1504.218443  2.985482
# 3           43.936066            4012.787947  4.127651

# %%
df.to_csv("segmented_customers.csv",index=False)
